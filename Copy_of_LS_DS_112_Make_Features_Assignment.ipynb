# %% [markdown]
# <a href="https://colab.research.google.com/github/kebreck/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Copy_of_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

import pandas as pd

# %%
! wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# LoanStats_2018Q4.cs     [               <=>  ]  22.05M  2.73MB/s    in 10s
#
# 2020-05-13 01:33:13 (2.19 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [23121687]
#
# --2020-05-13 01:33:14--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 35.163.140.110, 52.42.154.205, 52.32.67.162
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|35.163.140.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.1’
#
# LoanStats_2018Q4.cs     [          <=>       ]  22.05M  1.95MB/s    in 12s
#
# 2020-05-13 01:33:27 (1.85 MB/s) - ‘LoanStats_2018Q4.csv.zip.1’ saved [23121687]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
loans = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2)
loans.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
loans['term'][1]
# Out:
# ' 36 months'

# %%
type(int(loans['term'][1].strip().strip(' months')))
# Out:
# int

# %%
def stripFunc(input):
    return int(input.strip().strip(' months'))

# %%
term1 = ' 60 months'
print(term1)
# Out:
#  60 months

# %%
type(term1)
# Out:
# str

# %%
stripFunc(term1)
# Out:
# 60

# %%
type(stripFunc(term1))
# Out:
# int

# %%
loans['term_clean'] = loans['term'].apply(stripFunc)
loans['term_clean'].sample(10)
# Out:
# 127549    60
# 7088      36
# 61675     36
# 59860     36
# 126852    60
# 13623     36
# 89038     60
# 34217     36
# 59786     36
# 29714     36
# Name: term_clean, dtype: int64

# %%
loans.head()
# Out:
#    id  member_id  loan_amnt  ...  settlement_percentage  settlement_term term_clean
# 0 NaN        NaN      10000  ...                    NaN              NaN         60
# 1 NaN        NaN       6500  ...                    NaN              NaN         36
# 2 NaN        NaN       4500  ...                    NaN              NaN         36
# 3 NaN        NaN      25000  ...                    NaN              NaN         60
# 4 NaN        NaN      30000  ...                    NaN              NaN         60
#
# [5 rows x 145 columns]

# %%
# This method only returned 1... trying the other way
# def checkStatus(input):
#     if input == 'Current' or 'Fully Paid':
#       return 1
#     else:
#       return 0

# %%
checkStatus("Current")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-1e98fcd4c667> in <module>()
# ----> 1 checkStatus("Current")
#
# NameError: name 'checkStatus' is not defined

# %%
checkStatus('Fully Paid')

# %%
checkStatus('Charged Off')

# %%
loans['loan_status_is_great'] = 0
loans[['loan_status_is_great', 'loan_status']].head()

# %%
loans.loc[loans['loan_status']=='Current', 'loan_status_is_great'] = 1
loans.loc[loans['loan_status']=='Fully Paid', 'loan_status_is_great'] = 1
loans[['loan_status_is_great', 'loan_status']].head()

# %%
loans.columns.values.tolist()
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
# ...

# %%
loans['last_pymnt_d'].value_counts()
# Out:
# Apr-2020    73153
# Mar-2020    10734
# May-2020     7488
# Jul-2019     3146
# Sep-2019     2755
# Dec-2019     2730
# Oct-2019     2722
# Aug-2019     2716
# May-2019     2547
# Nov-2019     2388
# Apr-2019     2356
# Jan-2020     2336
# Jun-2019     2288
# Mar-2019     1984
# Feb-2019     1915
# Feb-2020     1858
# Jun-2020     1609
# Jan-2019     1561
# Dec-2018     1054
# Nov-2018      679
# Oct-2018      234
# Name: last_pymnt_d, dtype: int64

# %%
loans['last_pymnt_d_formatted'] = pd.to_datetime(loans['last_pymnt_d'], infer_datetime_format=True)

# %%
loans['last_pymnt_d_formatted'].dtype
# Out:
# dtype('<M8[ns]')

# %%
loans['last_pymnt_d_year'] = loans['last_pymnt_d_formatted'].dt.year
loans['last_pymnt_d_month'] = loans['last_pymnt_d_formatted'].dt.month
loans[['last_pymnt_d_formatted', 'last_pymnt_d_month', 'last_pymnt_d_year']].head()
# Out:
#   last_pymnt_d_formatted  last_pymnt_d_month  last_pymnt_d_year
# 0             2019-05-01                 5.0             2019.0
# 1             2020-03-01                 3.0             2020.0
# 2             2019-02-01                 2.0             2019.0
# 3             2019-10-01                10.0             2019.0
# 4             2020-03-01                 3.0             2020.0

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %%
list(pd.loans)

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
